# %% [markdown]
# Skenario tanpa melakukan data preparation terlebih dahulu

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# %%
import pandas as pd
path_data=r"C:\Users\wldn\Downloads\car_price_dataset.csv"
data = pd.read_csv(path_data)

data.head()
# Out:
#         Brand   Model  Year  Engine_Size Fuel_Type    Transmission  Mileage  \
# 0         Kia     Rio  2020          4.2    Diesel          Manual   289944
# 1   Chevrolet  Malibu  2012          2.0    Hybrid       Automatic     5356
# 2    Mercedes     GLA  2020          4.2    Diesel       Automatic   231440
# 3        Audi      Q5  2023          2.0  Electric          Manual   160971
# 4  Volkswagen    Golf  2003          2.6    Hybrid  Semi-Automatic   286618
#
#    Doors  Owner_Count  Price
# 0      3            5   8501
# 1      2            3  12092
# 2      4            2  11171
# 3      2            1  11780
# 4      3            3   2867

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         10000 non-null  object
#  1   Model         10000 non-null  object
#  2   Year          10000 non-null  int64
#  3   Engine_Size   10000 non-null  float64
#  4   Fuel_Type     10000 non-null  object
#  5   Transmission  10000 non-null  object
#  6   Mileage       10000 non-null  int64
#  7   Doors         10000 non-null  int64
#  8   Owner_Count   10000 non-null  int64
#  9   Price         10000 non-null  int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 781.4+ KB

# %%
data.describe()
# Out:
#                Year   Engine_Size        Mileage         Doors   Owner_Count  \
# count  10000.000000  10000.000000   10000.000000  10000.000000  10000.000000
# mean    2011.543700      3.000560  149239.111800      3.497100      2.991100
# std        6.897699      1.149324   86322.348957      1.110097      1.422682
# min     2000.000000      1.000000      25.000000      2.000000      1.000000
# 25%     2006.000000      2.000000   74649.250000      3.000000      2.000000
# 50%     2012.000000      3.000000  149587.000000      3.000000      3.000000
# 75%     2017.000000      4.000000  223577.500000      4.000000      4.000000
# max     2023.000000      5.000000  299947.000000      5.000000      5.000000
#
#              Price
# count  10000.00000
# mean    8852.96440
# std     3112.59681
# min     2000.00000
# 25%     6646.00000
# 50%     8858.50000
# 75%    11086.50000
# max    18301.00000

# %% [markdown]
# Analisis deskriptif pada data

# %%
numeric_summary = data.describe()
categorical_summary = data.select_dtypes(include = 'object').describe()

numeric_summary, categorical_summary
# Out:
# (               Year   Engine_Size        Mileage         Doors   Owner_Count  \
#  count  10000.000000  10000.000000   10000.000000  10000.000000  10000.000000
#  mean    2011.543700      3.000560  149239.111800      3.497100      2.991100
#  std        6.897699      1.149324   86322.348957      1.110097      1.422682
#  min     2000.000000      1.000000      25.000000      2.000000      1.000000
#  25%     2006.000000      2.000000   74649.250000      3.000000      2.000000
#  50%     2012.000000      3.000000  149587.000000      3.000000      3.000000
#  75%     2017.000000      4.000000  223577.500000      4.000000      4.000000
#  max     2023.000000      5.000000  299947.000000      5.000000      5.000000
#
#               Price
#  count  10000.00000
#  mean    8852.96440
#  std     3112.59681
#  min     2000.00000
#  25%     6646.00000
#  50%     8858.50000
#  75%    11086.50000
#  max    18301.00000  ,
#          Brand   Model Fuel_Type Transmission
# ...

# %%
# Cek distribusi fitur numerik
numerical_columns = ['Year', 'Engine_Size', 'Mileage', 'Doors', 'Owner_Count']

# Cek distribusi fitur kategorikal
categorical_columns = ['Brand', 'Model', 'Fuel_Type', 'Transmission']

# Plot untuk distribusi numerik
for col in numerical_columns:
    plt.figure(figsize=(8, 4))
    plt.hist(data[col].dropna(), bins=30, edgecolor='k', alpha=0.7)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# kolom categorical summary
categorical_summary = data[categorical_columns].apply(pd.Series.value_counts)

categorical_summary
# Out:
#                  Brand  Model  Fuel_Type  Transmission
# 3 Series           NaN  335.0        NaN           NaN
# 5 Series           NaN  353.0        NaN           NaN
# A3                 NaN  338.0        NaN           NaN
# A4                 NaN  350.0        NaN           NaN
# Accord             NaN  365.0        NaN           NaN
# Audi            1038.0    NaN        NaN           NaN
# Automatic          NaN    NaN        NaN        3317.0
# BMW              999.0    NaN        NaN           NaN
# C-Class            NaN  306.0        NaN           NaN
# CR-V               NaN  308.0        NaN           NaN
# Camry              NaN  321.0        NaN           NaN
# Chevrolet       1003.0    NaN        NaN           NaN
# Civic              NaN  336.0        NaN           NaN
# Corolla            NaN  325.0        NaN           NaN
# Diesel             NaN    NaN     2512.0           NaN
# E-Class            NaN  321.0        NaN           NaN
# ...

# %%
#distribusi kolom kategorikal
fig, axes = plt.subplots(1, 4, figsize=(18, 5))

# Distribusi Brand
data['Brand'].value_counts().plot(kind='bar', ax=axes[0], title='Distribution of Brand')

# distribusi Pclass (kelas penumpang)
data['Model'].value_counts().plot(kind='bar', ax=axes[1], title='Distribution of Model')

# distribusi Sex (jenis kelamin)
data['Fuel_Type'].value_counts().plot(kind='bar', ax=axes[2], title='Distribution of Fuel type')

# distribusi untuk embarked(pelabuhan)
data['Transmission'].value_counts().plot(kind='bar', ax=axes[3], title='Distribusion of Transmission')

plt.tight_layout()
plt.show()

# %%
#Distribusi untuk kolom numerik
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

#scatter untuk engine size vs price
axes[0, 0].scatter(data['Engine_Size'], data['Price'], alpha=0.8)
axes[0, 0].set_title('Engine Size vs Price')
axes[0, 0].set_xlabel('Engine_Size')
axes[0, 0].set_ylabel('Price')

#scatter untuk Year vs Price
axes[0, 1].scatter(data['Year'], data['Price'], alpha=0.8)
axes[0, 1].set_title('Year vs Price')
axes[0, 1].set_xlabel('Year')
axes[0, 1].set_ylabel('Price')

#scatter untuk Engine size vs year
axes[1, 0].scatter(data['Engine_Size'], data['Year'], alpha=0.8)
axes[1, 0].set_title('Engine Size vs Year')
axes[1, 0].set_xlabel('Engine_Size')
axes[1, 0].set_ylabel('Year')

#scatter untuk Mileage vs Price
axes[1, 1].scatter(data['Mileage'], data['Price'], alpha=0.8)
axes[1, 1].set_title('Mileage vs Price')
axes[1, 1].set_xlabel('Mileage')
axes[1, 1].set_ylabel('Price')

plt.tight_layout()
plt.show()

# %%
data.isnull().sum()
# Out:
# Brand           0
# Model           0
# Year            0
# Engine_Size     0
# Fuel_Type       0
# Transmission    0
# Mileage         0
# Doors           0
# Owner_Count     0
# Price           0
# dtype: int64

# %%
#Membuat visualisasi matriks korelasi dengan heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(data.corr(numeric_only=True), annot=True, fmt=".2f", cmap='magma', cbar=True, square=True)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
data.shape
# Out:
# (10000, 10)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score



# Target harga langsung (bukan kategori harga)
y = data['Price']

numerical_columns = ['Year', 'Engine_Size', 'Mileage', 'Doors', 'Owner_Count']
categorical_columns = ['Brand', 'Model', 'Fuel_Type', 'Transmission']

X = data.drop(columns=['Price'])

# Preprocessing: One-Hot Encoding untuk kolom kategorikal, passthrough untuk numerik
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_columns),  # Skala fitur numerik
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_columns)  # One-hot encoding untuk kategorikal
    ]
)

# Transformasi data
X_encoded = preprocessor.fit_transform(X)

# Split data menjadi training dan testing
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

results = {}

# Daftar model regresi untuk dievaluasi
models = {
    "Linear Regression": LinearRegression(),
    "Random Forest": RandomForestRegressor(),
    "Gradient Boosting": GradientBoostingRegressor(),
    "K-Nearest Neighbors": KNeighborsRegressor(),
    "Support Vector Machine": SVR(),
}

# Train dan evaluasi setiap model
for name, model in models.items():
    model.fit(X_train, y_train)  
    y_pred = model.predict(X_test)  
    
    # Menyimpan hasil evaluasi dengan metrik regresi
    results[name] = {
        "MAE": mean_absolute_error(y_test, y_pred),
        "MSE": mean_squared_error(y_test, y_pred),
        "RMSE": np.sqrt(mean_squared_error(y_test, y_pred)),
        "R2 Score": r2_score(y_test, y_pred),
    }

# Menampilkan hasil
results_df = pd.DataFrame(results).T

# %%
results_sorted = results_df.sort_values(by="R2 Score", ascending=False)
results_sorted
# Out:
#                                 MAE           MSE         RMSE  R2 Score
# Linear Regression         20.003593  4.213925e+03    64.914750  0.999541
# Gradient Boosting        169.547681  4.694337e+04   216.664186  0.994891
# Random Forest            256.558445  1.090792e+05   330.271374  0.988128
# K-Nearest Neighbors      848.874700  1.127307e+06  1061.747172  0.877304
# Support Vector Machine  2294.415306  7.993465e+06  2827.271588  0.129993

# %%
# Identify the best model based on Accuracy
best_model_name = results_sorted.index[0]
best_model = models[best_model_name]
best_model
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Prediksi harga
predictions = best_model.predict(X_test)

# Metrik evaluasi
mae = mean_absolute_error(y_test, predictions)
mse = mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, predictions)

# Print hasil evaluasi
print(f'Mean Absolute Error: {mae:.2f}')
print(f'Mean Squared Error: {mse:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'R² Score: {r2:.2f}')
# Out:
# Mean Absolute Error: 20.00
# Mean Squared Error: 4213.92
# Root Mean Squared Error: 64.91
# R² Score: 1.00
